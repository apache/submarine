# %% [markdown]
# ## Sample for Submarine Experiment SDK
#
# The notebook shows how to use Submarine Experiment SDK to create, get, list, log, delete Submarine Experiment.

# %%
from __future__ import print_function
import submarine
from submarine.client.models.environment_spec import EnvironmentSpec
from submarine.client.models.experiment_spec import ExperimentSpec
from submarine.client.models.experiment_task_spec import ExperimentTaskSpec
from submarine.client.models.experiment_meta import ExperimentMeta
from submarine.client.models.code_spec import CodeSpec

# %% [markdown]
# ### Create Submarine Client

# %%
# Host is "<SUBMARINE_SERVER_DNS_NAME>:<SUBMARINE_SERVER_PORT>" by default
# If you don't wanna use Jupyter notebook which generated by Submarine,
# please set the two environment variables "SUBMARINE_SERVER_DNS_NAME"
# (e.q. localhost) and "SUBMARINE_SERVER_PORT" (e.q. 8080).

# %%
submarine_client = submarine.ExperimentClient()

# %% [markdown]
# ### Define TensorFlow experiment spec¶
# Define Submarine spec¶
# The demo only creates a PS and worker of TF experiment to run mnist sample.

# %%
environment = EnvironmentSpec(image="apache/submarine:tf-dist-mnist-test-1.0")
experiment_meta = ExperimentMeta(
    name="mnist-dist",
    namespace="default",
    framework="Tensorflow",
    cmd="python /var/tf_dist_mnist/dist_mnist.py --train_steps=100",
    env_vars={"ENV1": "ENV1"},
)

worker_spec = ExperimentTaskSpec(resources="cpu=1,memory=1024M", replicas=1)
ps_spec = ExperimentTaskSpec(resources="cpu=1,memory=1024M", replicas=1)
code_spec = CodeSpec(sync_mode="git", url="https://github.com/apache/submarine.git")

experiment_spec = ExperimentSpec(
    meta=experiment_meta,
    environment=environment,
    code=code_spec,
    spec={"Ps": ps_spec, "Worker": worker_spec},
)

# %% [markdown]
# ### Create experiment

# %%
experiment = submarine_client.create_experiment(experiment_spec=experiment_spec)
experiment
# Out:
# {'experimentId': 'experiment-1640110858229-0006',
#  'uid': '0306270d-fd79-4a42-bd50-943ad7f9a3a3',
#  'status': 'Accepted',
#  'acceptedTime': '2021-12-22T02:33:56.000+08:00',
#  'createdTime': None,
#  'runningTime': None,
#  'finishedTime': None,
#  'spec': {'meta': {'experimentId': 'experiment-1640110858229-0006',
#    'name': 'mnist-dist',
#    'namespace': 'default',
#    'framework': 'Tensorflow',
#    'cmd': 'python /var/tf_dist_mnist/dist_mnist.py --train_steps=100',
#    'envVars': {'ENV1': 'ENV1'},
#    'tags': []},
#   'environment': {'name': None,
#    'dockerImage': None,
#    'kernelSpec': None,
#    'description': None,
#    'image': 'apache/submarine:tf-dist-mnist-test-1.0'},
#   'spec': {'Ps': {'replicas': 1,
#     'resources': 'cpu=1,memory=1024M',
#     'name': None,
#     'image': None,
#     'cmd': None,
#     'envVars': None,
#     'resourceMap': {'memory': '1024M', 'cpu': '1'}},
#    'Worker': {'replicas': 1,
#     'resources': 'cpu=1,memory=1024M',
#     'name': None,
#     'image': None,
#     'cmd': None,
#     'envVars': None,
#     'resourceMap': {'memory': '1024M', 'cpu': '1'}}},
#   'code': {'syncMode': 'git',
#    'url': 'https://github.com/apache/submarine.git'}}}

# %% [markdown]
# ### Get the created experiment

# %%
id = experiment["experimentId"]
submarine_client.get_experiment(id)
# Out:
# {'experimentId': 'experiment-1640110858229-0006',
#  'uid': '0306270d-fd79-4a42-bd50-943ad7f9a3a3',
#  'status': 'Created',
#  'acceptedTime': '2021-12-22T02:33:56.000+08:00',
#  'createdTime': '2021-12-22T02:33:56.000+08:00',
#  'runningTime': None,
#  'finishedTime': None,
#  'spec': {'meta': {'experimentId': 'experiment-1640110858229-0006',
#    'name': 'mnist-dist',
#    'namespace': 'default',
#    'framework': 'Tensorflow',
#    'cmd': 'python /var/tf_dist_mnist/dist_mnist.py --train_steps=100',
#    'envVars': {'ENV1': 'ENV1'},
#    'tags': []},
#   'environment': {'name': None,
#    'dockerImage': None,
#    'kernelSpec': None,
#    'description': None,
#    'image': 'apache/submarine:tf-dist-mnist-test-1.0'},
#   'spec': {'Ps': {'replicas': 1,
#     'resources': 'cpu=1,memory=1024M',
#     'name': None,
#     'image': None,
#     'cmd': None,
#     'envVars': None,
#     'resourceMap': {'memory': '1024M', 'cpu': '1'}},
#    'Worker': {'replicas': 1,
#     'resources': 'cpu=1,memory=1024M',
#     'name': None,
#     'image': None,
#     'cmd': None,
#     'envVars': None,
#     'resourceMap': {'memory': '1024M', 'cpu': '1'}}},
#   'code': {'syncMode': 'git',
#    'url': 'https://github.com/apache/submarine.git'}}}

# %% [markdown]
# ### List all running experiments

# %%
status = "running"
submarine_client.list_experiments(status=status)
# Out:
# []

# %% [markdown]
# ### Wait for the experiment to finish

# %%
submarine_client.wait_for_finish(id)
# Out:
# /usr/local/lib/python2.7/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# 2021-12-21 18:34:09.528066: I tensorflow/core/platform/cpu_feature_guard.cc:137] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2 FMA
# 2021-12-21 18:34:09.529126: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:215] Initialize GrpcChannelCache for job ps -> {0 -> localhost:2222}
# 2021-12-21 18:34:09.529164: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:215] Initialize GrpcChannelCache for job worker -> {0 -> experiment-1640110858229-0006-worker-0.default.svc:2222}
# 2021-12-21 18:34:09.529732: I tensorflow/core/distributed_runtime/rpc/grpc_server_lib.cc:324] Started server with target: grpc://localhost:2222

# %% [markdown]
# ### Get specific experiment training log

# %%
submarine_client.get_log(id)
# Out:
# The logs of Pod experiment-1640110858229-0006-ps-0:
#
# /usr/local/lib/python2.7/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# 2021-12-21 18:34:09.528066: I tensorflow/core/platform/cpu_feature_guard.cc:137] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2 FMA
# 2021-12-21 18:34:09.529126: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:215] Initialize GrpcChannelCache for job ps -> {0 -> localhost:2222}
# 2021-12-21 18:34:09.529164: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:215] Initialize GrpcChannelCache for job worker -> {0 -> experiment-1640110858229-0006-worker-0.default.svc:2222}
# 2021-12-21 18:34:09.529732: I tensorflow/core/distributed_runtime/rpc/grpc_server_lib.cc:324] Started server with target: grpc://localhost:2222
# The logs of Pod experiment-1640110858229-0006-worker-0:
#
# /usr/local/lib/python2.7/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# 2021-12-21 18:34:08.093849: I tensorflow/core/platform/cpu_feature_guard.cc:137] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2 FMA
# 2021-12-21 18:34:08.095284: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:215] Initialize GrpcChannelCache for job ps -> {0 -> experiment-1640110858229-0006-ps-0.default.svc:2222}
# 2021-12-21 18:34:08.095334: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:215] Initialize GrpcChannelCache for job worker -> {0 -> localhost:2222}
# 2021-12-21 18:34:08.096235: I tensorflow/core/distributed_runtime/rpc/grpc_server_lib.cc:324] Started server with target: grpc://localhost:2222
# WARNING:tensorflow:From /var/tf_dist_mnist/dist_mnist.py:239: __init__ (from tensorflow.python.training.supervisor) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please switch to tf.train.MonitoredTrainingSession
# 2021-12-21 18:34:10.457283: I tensorflow/core/distributed_runtime/master_session.cc:1017] Start master session 7124f68422637964 with config: device_filters: "/job:ps" device_filters: "/job:worker/task:0" allow_soft_placement: true
# Successfully downloaded train-images-idx3-ubyte.gz 9912422 bytes.
# Extracting /tmp/mnist-data/train-images-idx3-ubyte.gz
# Successfully downloaded train-labels-idx1-ubyte.gz 28881 bytes.
# Extracting /tmp/mnist-data/train-labels-idx1-ubyte.gz
# Successfully downloaded t10k-images-idx3-ubyte.gz 1648877 bytes.
# Extracting /tmp/mnist-data/t10k-images-idx3-ubyte.gz
# Successfully downloaded t10k-labels-idx1-ubyte.gz 4542 bytes.
# Extracting /tmp/mnist-data/t10k-labels-idx1-ubyte.gz
# job name = worker
# task index = 0
# Worker 0: Initializing session...
# Worker 0: Session initialization complete.
# Training begins @ 1640111650.733849
# 1640111650.969133: Worker 0: training step 1 done (global step: 0)
# 1640111650.978049: Worker 0: training step 2 done (global step: 1)
# 1640111650.989931: Worker 0: training step 3 done (global step: 2)
# 1640111650.999159: Worker 0: training step 4 done (global step: 3)
# 1640111651.008751: Worker 0: training step 5 done (global step: 4)
# 1640111651.052865: Worker 0: training step 6 done (global step: 5)
# 1640111651.063632: Worker 0: training step 7 done (global step: 6)
# 1640111651.072713: Worker 0: training step 8 done (global step: 7)
# 1640111651.082712: Worker 0: training step 9 done (global step: 8)
# 1640111651.094652: Worker 0: training step 10 done (global step: 9)
# 1640111651.105416: Worker 0: training step 11 done (global step: 10)
# 1640111651.153330: Worker 0: training step 12 done (global step: 11)
# 1640111651.163832: Worker 0: training step 13 done (global step: 12)
# 1640111651.173664: Worker 0: training step 14 done (global step: 13)
# 1640111651.182991: Worker 0: training step 15 done (global step: 14)
# 1640111651.191109: Worker 0: training step 16 done (global step: 15)
# 1640111651.199726: Worker 0: training step 17 done (global step: 16)
# 1640111651.250473: Worker 0: training step 18 done (global step: 17)
# 1640111651.258586: Worker 0: training step 19 done (global step: 18)
# 1640111651.266307: Worker 0: training step 20 done (global step: 19)
# 1640111651.275668: Worker 0: training step 21 done (global step: 20)
# 1640111651.283407: Worker 0: training step 22 done (global step: 21)
# 1640111651.291265: Worker 0: training step 23 done (global step: 22)
# 1640111651.299381: Worker 0: training step 24 done (global step: 23)
# 1640111651.305669: Worker 0: training step 25 done (global step: 24)
# 1640111651.352488: Worker 0: training step 26 done (global step: 25)
# 1640111651.359732: Worker 0: training step 27 done (global step: 26)
# 1640111651.365766: Worker 0: training step 28 done (global step: 27)
# 1640111651.372034: Worker 0: training step 29 done (global step: 28)
# 1640111651.378381: Worker 0: training step 30 done (global step: 29)
# 1640111651.384172: Worker 0: training step 31 done (global step: 30)
# 1640111651.391027: Worker 0: training step 32 done (global step: 31)
# 1640111651.404218: Worker 0: training step 33 done (global step: 32)
# 1640111651.410167: Worker 0: training step 34 done (global step: 33)
# 1640111651.451277: Worker 0: training step 35 done (global step: 34)
# 1640111651.458168: Worker 0: training step 36 done (global step: 35)
# 1640111651.496320: Worker 0: training step 37 done (global step: 36)
# 1640111651.502132: Worker 0: training step 38 done (global step: 37)
# 1640111651.507339: Worker 0: training step 39 done (global step: 38)
# 1640111651.512701: Worker 0: training step 40 done (global step: 39)
# 1640111651.517597: Worker 0: training step 41 done (global step: 40)
# 1640111651.523119: Worker 0: training step 42 done (global step: 41)
# 1640111651.528645: Worker 0: training step 43 done (global step: 42)
# 1640111651.534247: Worker 0: training step 44 done (global step: 43)
# 1640111651.550153: Worker 0: training step 45 done (global step: 44)
# 1640111651.556111: Worker 0: training step 46 done (global step: 45)
# 1640111651.561790: Worker 0: training step 47 done (global step: 46)
# 1640111651.567773: Worker 0: training step 48 done (global step: 47)
# 1640111651.573042: Worker 0: training step 49 done (global step: 48)
# 1640111651.578469: Worker 0: training step 50 done (global step: 49)
# 1640111651.584431: Worker 0: training step 51 done (global step: 50)
# 1640111651.590252: Worker 0: training step 52 done (global step: 51)
# 1640111651.595784: Worker 0: training step 53 done (global step: 52)
# 1640111651.649612: Worker 0: training step 54 done (global step: 53)
# 1640111651.655372: Worker 0: training step 55 done (global step: 54)
# 1640111651.660762: Worker 0: training step 56 done (global step: 55)
# 1640111651.666178: Worker 0: training step 57 done (global step: 56)
# 1640111651.673080: Worker 0: training step 58 done (global step: 57)
# 1640111651.678989: Worker 0: training step 59 done (global step: 58)
# 1640111651.684430: Worker 0: training step 60 done (global step: 59)
# 1640111651.690468: Worker 0: training step 61 done (global step: 60)
# 1640111651.696054: Worker 0: training step 62 done (global step: 61)
# 1640111651.703274: Worker 0: training step 63 done (global step: 62)
# 1640111651.750652: Worker 0: training step 64 done (global step: 63)
# 1640111651.756330: Worker 0: training step 65 done (global step: 64)
# 1640111651.761865: Worker 0: training step 66 done (global step: 65)
# 1640111651.767066: Worker 0: training step 67 done (global step: 66)
# 1640111651.773966: Worker 0: training step 68 done (global step: 67)
# 1640111651.790034: Worker 0: training step 69 done (global step: 68)
# 1640111651.801731: Worker 0: training step 70 done (global step: 69)
# 1640111651.812638: Worker 0: training step 71 done (global step: 70)
# 1640111651.851214: Worker 0: training step 72 done (global step: 71)
# 1640111651.860038: Worker 0: training step 73 done (global step: 72)
# 1640111651.868899: Worker 0: training step 74 done (global step: 73)
# 1640111651.886605: Worker 0: training step 75 done (global step: 74)
# 1640111651.896981: Worker 0: training step 76 done (global step: 75)
# 1640111651.907400: Worker 0: training step 77 done (global step: 76)
# 1640111651.937603: Worker 0: training step 78 done (global step: 77)
# 1640111651.951628: Worker 0: training step 79 done (global step: 78)
# 1640111651.958359: Worker 0: training step 80 done (global step: 79)
# 1640111651.966299: Worker 0: training step 81 done (global step: 80)
# 1640111651.974218: Worker 0: training step 82 done (global step: 81)
# 1640111651.982264: Worker 0: training step 83 done (global step: 82)
# 1640111651.989423: Worker 0: training step 84 done (global step: 83)
# 1640111651.997561: Worker 0: training step 85 done (global step: 84)
# 1640111652.004062: Worker 0: training step 86 done (global step: 85)
# 1640111652.051784: Worker 0: training step 87 done (global step: 86)
# 1640111652.057463: Worker 0: training step 88 done (global step: 87)
# 1640111652.065215: Worker 0: training step 89 done (global step: 88)
# 1640111652.072090: Worker 0: training step 90 done (global step: 89)
# 1640111652.078558: Worker 0: training step 91 done (global step: 90)
# 1640111652.085314: Worker 0: training step 92 done (global step: 91)
# 1640111652.091121: Worker 0: training step 93 done (global step: 92)
# 1640111652.096206: Worker 0: training step 94 done (global step: 93)
# 1640111652.101504: Worker 0: training step 95 done (global step: 94)
# 1640111652.151558: Worker 0: training step 96 done (global step: 95)
# 1640111652.158660: Worker 0: training step 97 done (global step: 96)
# 1640111652.164154: Worker 0: training step 98 done (global step: 97)
# 1640111652.170239: Worker 0: training step 99 done (global step: 98)
# 1640111652.176086: Worker 0: training step 100 done (global step: 99)
# 1640111652.181573: Worker 0: training step 101 done (global step: 100)
# Training ends @ 1640111652.181647
# Training elapsed time: 1.447798 s
# After 100 training step(s), validation cross entropy = 1294.33

# %% [markdown]
# ### Delete the experiment

# %%
submarine_client.delete_experiment(id)
# Out:
# {'experimentId': 'experiment-1640110858229-0006',
#  'uid': '0306270d-fd79-4a42-bd50-943ad7f9a3a3',
#  'status': 'Deleted',
#  'acceptedTime': None,
#  'createdTime': None,
#  'runningTime': None,
#  'finishedTime': None,
#  'spec': {'meta': {'experimentId': 'experiment-1640110858229-0006',
#    'name': 'mnist-dist',
#    'namespace': 'default',
#    'framework': 'Tensorflow',
#    'cmd': 'python /var/tf_dist_mnist/dist_mnist.py --train_steps=100',
#    'envVars': {'ENV1': 'ENV1'},
#    'tags': []},
#   'environment': {'name': None,
#    'dockerImage': None,
#    'kernelSpec': None,
#    'description': None,
#    'image': 'apache/submarine:tf-dist-mnist-test-1.0'},
#   'spec': {'Ps': {'replicas': 1,
#     'resources': 'cpu=1,memory=1024M',
#     'name': None,
#     'image': None,
#     'cmd': None,
#     'envVars': None,
#     'resourceMap': {'memory': '1024M', 'cpu': '1'}},
#    'Worker': {'replicas': 1,
#     'resources': 'cpu=1,memory=1024M',
#     'name': None,
#     'image': None,
#     'cmd': None,
#     'envVars': None,
#     'resourceMap': {'memory': '1024M', 'cpu': '1'}}},
#   'code': {'syncMode': 'git',
#    'url': 'https://github.com/apache/submarine.git'}}}
